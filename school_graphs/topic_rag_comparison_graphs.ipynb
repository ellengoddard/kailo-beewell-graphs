# %%
import os

import matplotlib.pyplot as plt
import pandas as pd
from rag_schools_comparison_graph import School, make_comparison_graph


def save_graph(file_path, figure) -> None:  # noqa: ANN001
    """Save the graph."""
    directory = os.path.dirname(file_path)  # noqa: PTH120
    if not os.path.exists(directory):  # noqa: PTH110
        os.makedirs(directory)  # noqa: PTH103
    figure.savefig(file_path, dpi=120, pad_inches=0.4, bbox_inches="tight")
    plt.close(figure)

# %%
rag_df = pd.read_csv(
    "../data/real/standard_area_aggregate_scores_rag.csv",
)


# Replace specific values in 'variable_lab' for clarity
rag_df["variable_lab"] = rag_df["variable_lab"].replace(
    {
        "Taking to staff about feelings": "Talking to staff about feelings",
        "Taking at home about feelings": "Talking at home about feelings",
        "Taking to peers about feelings": "Talking to peers about feelings",
        "Talking about feelings": "General talking about feelings",  # Keep temporarily for confirmation
    }
)

# Update 'group' column and relevant 'variable_lab' and 'description' values
rag_df.loc[rag_df["variable"] == "staff_talk_score", ["variable_lab", "description", "group"]] = [
    "Talking to staff about feelings",
    "How positively/negatively young people feel about talking with staff about feeling down",
    "staff_talk",
]

rag_df.loc[rag_df["variable"] == "peer_talk_score", ["variable_lab", "description", "group"]] = [
    "Talking to peers about feelings",
    "How positively/negatively young people feel about talking with peers about feeling down",
    "peer_talk",
]

rag_df.loc[rag_df["variable"] == "home_talk_score", ["variable_lab", "description", "group"]] = [
    "Talking at home about feelings",
    "How positively/negatively young people feel about talking at home about feeling down",
    "home_talk",
]

# Remove rows where 'variable' is 'talk_score' to exclude redundant entries
rag_df = rag_df[rag_df["variable"] != "talk_score"]

# %%
schools = rag_df["school_lab"].unique()
topics = rag_df["variable"].unique()

# Base subgroup filters
subgroup_filter_functions = {
    "Year 8": lambda df: df[df["year_group_lab"] == "Year 8"],
    "Year 10": lambda df: df[df["year_group_lab"] == "Year 10"],
    "SEN": lambda df: df[df["sen_lab"] == "SEN"],
    "Non-SEN": lambda df: df[df["sen_lab"] == "Non-SEN"],
    "FSM": lambda df: df[df["fsm_lab"] == "FSM"],
    "Non-FSM": lambda df: df[df["fsm_lab"] == "Non-FSM"],
    "Boy": lambda df: df[df["gender_lab"] == "Boy"],
    "Girl": lambda df: df[df["gender_lab"] == "Girl"],
    "All": lambda df: df[
        (df["year_group_lab"] == "All") &
        (df["fsm_lab"] == "All") &
        (df["sen_lab"] == "All") &
        (df["gender_lab"] == "All")
    ],  # Returns rows where all filters match "All"
}

# %%
# Loop over each school
for school in schools:
    # Filter DataFrame for the current school
    school_df = rag_df[rag_df["school_lab"] == school]

    # Loop over each subgroup filter
    for subgroup_name, subgroup_filter in subgroup_filter_functions.items():
        # Apply the subgroup filter to the school's DataFrame
        subgroup_df_for_school = subgroup_filter(school_df)

        # Loop over each topic
        for topic in topics:
            print(f"Processing {school}...")  # noqa: T201
            print(f"Processing {subgroup_name} for {school}...")  # noqa: T201
            print(f"Processing topic '{topic}' for {school} under {subgroup_name}...")  # noqa: T201
            print("\n")  # noqa: T201
            # Filter the DataFrame for the current topic
            filtered_df = subgroup_df_for_school[subgroup_df_for_school["variable"] == topic]

            # Check if there is data to process
            if filtered_df.empty:
                continue  # Skip if no data for this combination

            # Compute mean score for the current school, subgroup, and topic
            current_school_mean = filtered_df["mean"].values[0]

            # Get data for all schools (including the current school)
            all_schools_df: pd.DataFrame = rag_df[rag_df["variable"] == topic]
            all_schools_df = subgroup_filter(all_schools_df)

            # Check if there is data for all schools
            if all_schools_df.empty:
                continue  # Skip if no data

            # Compute mean scores for all schools and sort them
            all_schools_means = all_schools_df.set_index("school_lab")["mean"].sort_values()

            # Create School objects for all schools in sorted order
            all_schools = [
                School(school_name=school_name, mean_topic_score=mean)
                for school_name, mean in all_schools_means.items()
            ]

            # Identify the index of the current school in the sorted list, if it exists
            if school in all_schools_means.index:
                current_school_mean = all_schools_means.loc[school]
                current_school = School(
                    mean_topic_score=current_school_mean,
                    school_name=school,
                )
            else:
                # Handle missing school appropriately here
                current_school = None

            # Determine y-axis range
            range_low = all_schools_means.min() - (all_schools_means.min()/10)
            range_high = all_schools_means.max() + (all_schools_means.max()/10)

            # Labels for the graph
            y_label = "Mean score"
            x_label = "Northern Devon schools (ordered by mean score)"

            # Calculate overall statistics
            overall_mean = all_schools_df["group_wt_mean"].values[0]
            below_avg_amount = all_schools_df["lower"].values[0]
            above_avg_amount = all_schools_df["upper"].values[0]
            average_amount = overall_mean
            print("current_school: ", current_school)
            # Generate the graph and get the figure
            figure = make_comparison_graph(
                schools=all_schools,
                range_low=range_low,
                range_high=range_high,
                y_label=y_label,
                x_label=x_label,
                below_avg_amount=below_avg_amount,
                above_avg_amount=above_avg_amount,
                current_school=current_school,
            )



            # Save the figure using your save_graph function
            filename = f"outputs/{school}/rag_comparison/{subgroup_name}/{topic}.png"
            save_graph(filename, figure)
# Out:
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'autonomy_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(19.859060402684563), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'life_satisfaction_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(6.9072847682119205), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'optimism_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(11.61111111111111), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wellbeing_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(22.859060402684563), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'esteem_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(14.72), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'stress_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(9.06081081081081), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'appearance_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(6.2827586206896555), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'negative_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(13.899328859060402), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'lonely_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(3.4407894736842106), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'support_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(5.993377483443709), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'sleep_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(0.5909090909090909), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'physical_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(454.4805194805195), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'free_like_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(4.025974025974026), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'media_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(4.253246753246753), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'places_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(2.7218543046357615), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_talk_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(2.2384868421052633), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_talk_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(3.0416666666666665), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'peer_talk_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(2.5745033112582782), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'accept_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(12.644736842105264), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'school_belong_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(3.590909090909091), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_relationship_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(13.935064935064934), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_relationship_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(17.006451612903227), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_happy_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(8.324675324675324), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'local_env_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(18.624113475177303), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'discrim_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(1.7243589743589745), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'belong_local_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(3.161290322580645), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wealth_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(0.6692913385826772), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'future_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(8.99047619047619), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'climate_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(2.418300653594771), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'social_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(15.894736842105264), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 8 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'bully_score' for BRAUNTON SCHOOL AND C.C. under Year 8...
#
#
# current_school:  School(mean_topic_score=np.float64(10.64), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'autonomy_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(20.2109375), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'life_satisfaction_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(6.90625), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'optimism_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(11.181102362204724), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wellbeing_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(22.89763779527559), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'esteem_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(14.601626016260164), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'stress_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(9.24390243902439), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'appearance_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(6.333333333333333), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'negative_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(13.696), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'lonely_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(3.5114503816793894), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'support_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(6.023076923076923), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'sleep_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(0.6349206349206349), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'physical_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(453.0952380952381), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'free_like_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(4.0476190476190474), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'media_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(4.771653543307087), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'places_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(2.425196850393701), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_talk_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(2.3174603174603177), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_talk_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(3.0688976377952755), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'peer_talk_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(2.6483739837398375), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'accept_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(12.456), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'school_belong_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(3.3858267716535435), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_relationship_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(14.8), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_relationship_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(17.302325581395348), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_happy_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(8.534883720930232), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'local_env_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(18.390243902439035), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'discrim_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(1.7674418604651163), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'belong_local_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(3.078125), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wealth_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(0.5238095238095238), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'future_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(8.427884615384615), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'climate_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(2.4728682170542635), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'social_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(15.04), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Year 10 for BRAUNTON SCHOOL AND C.C....
# Processing topic 'bully_score' for BRAUNTON SCHOOL AND C.C. under Year 10...
#
#
# current_school:  School(mean_topic_score=np.float64(10.9765625), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'autonomy_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(20.1875), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'life_satisfaction_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(6.366666666666666), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'optimism_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(10.766666666666667), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wellbeing_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(21.433333333333337), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'esteem_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(13.0625), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'stress_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(8.096774193548388), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'appearance_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(5.5), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'negative_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(12.5), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'lonely_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.1470588235294117), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'support_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(5.794117647058823), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'sleep_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(0.5454545454545454), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'physical_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(375.0), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'free_like_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.911764705882353), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'media_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.823529411764706), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'places_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.235294117647059), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_talk_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.2578125), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_talk_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.8823529411764706), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'peer_talk_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.2265625), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'accept_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(11.25), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'school_belong_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.8823529411764706), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_relationship_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(13.46875), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_relationship_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(16.0), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_happy_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(7.272727272727272), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'local_env_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(17.451612903225808), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'discrim_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(1.5588235294117647), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'belong_local_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.088235294117647), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wealth_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(0.4285714285714285), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'future_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(8.382352941176471), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'climate_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.5806451612903225), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'social_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(13.866666666666667), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'bully_score' for BRAUNTON SCHOOL AND C.C. under SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(10.225806451612904), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'autonomy_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(20.0), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'life_satisfaction_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(6.971887550200803), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'optimism_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(11.489626556016598), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wellbeing_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(23.052845528455286), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'esteem_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(14.879668049792532), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'stress_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(9.279166666666669), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'appearance_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(6.407563025210084), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'negative_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(13.979338842975206), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'lonely_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.5180722891566263), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'support_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(6.036437246963563), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'sleep_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(0.6194331983805668), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'physical_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(464.7560975609756), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'free_like_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(4.0528455284552845), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'media_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(4.578947368421052), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'places_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.6352459016393444), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_talk_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.2764227642276422), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_talk_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.0773092369477912), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'peer_talk_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.6580578512396693), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'accept_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(12.73061224489796), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'school_belong_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.582995951417004), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_relationship_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(14.433198380566802), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_relationship_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(17.290836653386453), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_happy_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(8.572), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'local_env_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(18.656652360515), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'discrim_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(1.7689243027888446), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'belong_local_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(3.1285140562248994), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wealth_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(0.6208530805687204), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'future_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(8.739583333333334), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'climate_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(2.4262948207171315), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'social_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(15.708502024291498), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-SEN for BRAUNTON SCHOOL AND C.C....
# Processing topic 'bully_score' for BRAUNTON SCHOOL AND C.C. under Non-SEN...
#
#
# current_school:  School(mean_topic_score=np.float64(10.866396761133604), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'autonomy_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(17.571428571428573), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'life_satisfaction_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(5.235294117647059), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'optimism_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(9.580645161290322), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wellbeing_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(18.97142857142857), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'esteem_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(12.93939393939394), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'stress_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(8.028571428571428), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'appearance_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(4.65625), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'negative_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(11.83783783783784), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'lonely_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(3.081081081081081), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'support_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(5.8), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'sleep_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(0.4848484848484848), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'physical_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(331.7647058823529), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'free_like_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(3.7714285714285714), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'media_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(3.0), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'places_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.323529411764706), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_talk_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.3055555555555554), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_talk_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.638888888888889), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'peer_talk_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.5069444444444446), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'accept_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(11.588235294117649), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'school_belong_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(3.0277777777777777), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_relationship_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(13.411764705882351), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_relationship_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(14.88888888888889), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'home_happy_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(7.647058823529412), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'local_env_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(17.13541666666667), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'discrim_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(1.542857142857143), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'belong_local_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.8857142857142857), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wealth_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(0.3571428571428571), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'future_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(7.886363636363637), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'climate_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.7142857142857144), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'social_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(13.914285714285716), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'bully_score' for BRAUNTON SCHOOL AND C.C. under FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(10.166666666666666), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'autonomy_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(20.37603305785124), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'life_satisfaction_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(7.1387755102040815), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'optimism_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(11.645833333333334), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'wellbeing_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(23.443983402489625), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'esteem_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(14.904166666666669), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'stress_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(9.309322033898304), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'appearance_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(6.529661016949152), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'negative_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(14.113924050632912), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'lonely_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(3.532520325203252), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'support_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(6.036585365853658), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'sleep_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(0.6275303643724697), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'physical_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(470.7317073170732), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'free_like_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(4.073469387755102), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'media_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(4.699186991869919), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'places_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.622950819672131), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# Processing topic 'staff_talk_score' for BRAUNTON SCHOOL AND C.C. under Non-FSM...
#
#
# current_school:  School(mean_topic_score=np.float64(2.269628099173554), school_name='BRAUNTON SCHOOL AND C.C.')
# Processing BRAUNTON SCHOOL AND C.C....
# Processing Non-FSM for BRAUNTON SCHOOL AND C.C....
# ...
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'wellbeing_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(19.290076335877863), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'esteem_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(12.221374045801529), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'stress_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(6.676923076923077), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'appearance_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(4.354330708661418), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'negative_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(9.376923076923076), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'lonely_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.553956834532374), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'support_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(5.2611940298507465), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'sleep_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(0.373134328358209), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'physical_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(327.9389312977099), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'free_like_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(3.8582089552238807), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'media_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(3.251851851851852), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'places_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.1278195488721803), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'staff_talk_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(1.987037037037037), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'home_talk_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.340909090909091), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'peer_talk_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.3400735294117645), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'accept_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(10.590551181102365), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'school_belong_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.6791044776119404), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'staff_relationship_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(12.903703703703703), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'home_relationship_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(15.963503649635037), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'home_happy_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(6.875912408759124), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'local_env_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(15.517906336088156), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'discrim_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(1.544776119402985), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'belong_local_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.7518796992481205), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'wealth_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(0.5818181818181818), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'future_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(7.163157894736842), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'climate_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(2.5808823529411766), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'social_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(13.992647058823527), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing Girl for THE ILFRACOMBE ACADEMY...
# Processing topic 'bully_score' for THE ILFRACOMBE ACADEMY under Girl...
#
#
# current_school:  School(mean_topic_score=np.float64(10.362962962962962), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'autonomy_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(18.333333333333332), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'life_satisfaction_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(6.0174672489082965), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'optimism_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(10.669683257918551), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'wellbeing_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(20.87224669603524), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'esteem_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(13.309417040358744), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'stress_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(7.773755656108597), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'appearance_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(5.19634703196347), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'negative_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(11.49099099099099), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'lonely_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.903361344537815), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'support_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(5.5064935064935066), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'sleep_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(0.5), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'physical_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(382.86995515695065), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'free_like_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(4.030973451327434), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'media_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(3.628318584070796), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'places_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.235294117647059), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'staff_talk_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.1084070796460175), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'home_talk_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.5253303964757707), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'peer_talk_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.403587443946188), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'accept_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(11.38888888888889), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'school_belong_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.948051948051948), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'staff_relationship_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(13.706140350877194), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'home_relationship_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(16.46551724137931), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'home_happy_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(7.5256410256410255), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'local_env_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(16.470125786163514), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'discrim_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(1.6347826086956525), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'belong_local_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.912663755458515), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'wealth_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(0.5489130434782609), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'future_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(7.695783132530121), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'climate_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(2.665217391304348), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'social_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(14.2882096069869), school_name='THE ILFRACOMBE ACADEMY')
# Processing THE ILFRACOMBE ACADEMY...
# Processing All for THE ILFRACOMBE ACADEMY...
# Processing topic 'bully_score' for THE ILFRACOMBE ACADEMY under All...
#
#
# current_school:  School(mean_topic_score=np.float64(10.384279475982533), school_name='THE ILFRACOMBE ACADEMY')
